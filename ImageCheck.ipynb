# %% [markdown]
# <a href="https://colab.research.google.com/github/harvardnlp/image-extraction/blob/master/ImageCheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/harvardnlp/image-extraction/
# Out:
# Cloning into 'image-extraction'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 18 (delta 6), reused 10 (delta 3), pack-reused 0
# Unpacking objects: 100% (18/18), done.

# %%
# !cd image-extraction; bash setup.sh
# Out:
# ...
#   Cloning https://github.com/facebookresearch/fvcore.git to /tmp/pip-req-build-gaio27aa
#   Running command git clone -q https://github.com/facebookresearch/fvcore.git /tmp/pip-req-build-gaio27aa
# ...
#      |████████████████████████████████| 276kB 33.0MB/s
# ...
#   Created wheel for fvcore: filename=fvcore-0.1-cp36-none-any.whl size=44465 sha256=604c34a49c02d98462d9dc765c366baa93fcb9dd8480782efcfa5c575d36f621
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mu7wx_ps/wheels/48/53/79/3c6485543a4455a0006f5db590ab9957622b6227011941de06
# ...
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=ee44bc971b23ac7661e47db4543bc8630b65f741065024d15044f057bb401d95
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built fvcore pyyaml
# ...
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
# Cloning into 'detectron_repo'...
# ...

# %%
# !mkdir pdfs/; rm pdfs/*
# !cd pdfs/; wget https://openreview.net/pdf?id=mllQ3QNNr9d; mv pdf?id=mllQ3QNNr9d mllQ3QNNr9d.pdf
# !cd pdfs/; wget https://openreview.net/pdf?id=q2noHUqMkK; mv pdf?id=q2noHUqMkK q2noHUqMkK.pdf
# Out:
# mkdir: cannot create directory ‘pdfs/’: File exists
# --2020-05-07 13:45:36--  https://openreview.net/pdf?id=mllQ3QNNr9d
# Resolving openreview.net (openreview.net)... 35.184.86.251
# Connecting to openreview.net (openreview.net)|35.184.86.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 673075 (657K) [application/pdf]
# Saving to: ‘pdf?id=mllQ3QNNr9d’
#
# pdf?id=mllQ3QNNr9d  100%[===================>] 657.30K  4.00MB/s    in 0.2s
#
# 2020-05-07 13:45:36 (4.00 MB/s) - ‘pdf?id=mllQ3QNNr9d’ saved [673075/673075]
#
# --2020-05-07 13:45:36--  https://openreview.net/pdf?id=q2noHUqMkK
# Resolving openreview.net (openreview.net)... 35.184.86.251
# Connecting to openreview.net (openreview.net)|35.184.86.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4934561 (4.7M) [application/pdf]
# Saving to: ‘pdf?id=q2noHUqMkK’
#
# pdf?id=q2noHUqMkK   100%[===================>]   4.71M  16.7MB/s    in 0.3s
#
# ...

# %%
# !mkdir pics
# !cd image-extraction; python run.py ../pdfs ../pics
# Out:
# mkdir: cannot create directory ‘pics’: File exists
# mkdir: cannot create directory ‘dataset’: File exists
# mkdir: cannot create directory ‘out’: File exists
# 0
# Saving  ../pics/mllQ3QNNr9d.pdf.png
# 0
# Saving  ../pics/q2noHUqMkK.pdf.png
# 1
# 2
# 3

# %%
# !ls pics
# Out:
# mllQ3QNNr9d.pdf.png  q2noHUqMkK.pdf.png

# %%
from IPython.display import Image
Image("pics/q2noHUqMkK.pdf.png")
